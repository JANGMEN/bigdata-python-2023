# %% [markdown]
# #### Pandas Dataframe by Database
#
# ##### DB모듈
#
# - MySQL : pymysql 모듈 설치
# - Oracle : cx_Oracle
# - SQL server : pymssql

# %%
# !pip install pymysql
# Out:
# ...
#                                               0.0/43.7 kB ? eta -:--:--
#      ---------------------------------------- 43.7/43.7 kB 2.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import pymysql

# %%
conn = pymysql.connect(host='210.119.14.56', port=3306, user='root', password='12345', db='sakila')
query = 'SELECT * FROM actor'

df = pd.read_sql_query(query, conn)
print('조회완료')
# Out:
# 조회완료
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_12072\183394569.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %%
df
# Out:
#      actor_id first_name     last_name         last_update
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2           3         ED         CHASE 2006-02-15 04:34:33
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
# ..        ...        ...           ...                 ...
# 195       196       BELA        WALKEN 2006-02-15 04:34:33
# 196       197      REESE          WEST 2006-02-15 04:34:33
# 197       198       MARY        KEITEL 2006-02-15 04:34:33
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33
#
# [200 rows x 4 columns]

# %%
df.to_csv('./actor_list.csv', encoding='utf-8', index=False)

# %% [markdown]
# ##### 추가 팁

# %%
titanic = pd.read_csv('./data/titanic_train.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.options.display.max_rows = 100 # 최대 행수를 100개 지정
titanic.head(100)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
# jinja2 설치
# !pip install Jinja2
# Out:
# ...
#                                               0.0/133.1 kB ? eta -:--:--
#      ---------                               30.7/133.1 kB 1.3 MB/s eta 0:00:01
#      --------------------------------       112.6/133.1 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 133.1/133.1 kB 1.1 MB/s eta 0:00:00
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_train2 = titanic[['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']]
titanic_train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Age          714 non-null    float64
#  4   SibSp        891 non-null    int64
#  5   Parch        891 non-null    int64
#  6   Fare         891 non-null    float64
# dtypes: float64(2), int64(5)
# memory usage: 48.9 KB

# %%
titanic_train2.head(100).style.highlight_max(color='lightgreen')
# Out:
# <style type="text/css">
# ...

# %%
titanic_train2.head(100).style.highlight_min(color='orange')
# Out:
# <style type="text/css">
# ...

# %%
titanic_train2.head(100).style.highlight_null(color='darkgray')
# Out:
# <style type="text/css">
# #T_78ced_row5_col3, #T_78ced_row17_col3, #T_78ced_row19_col3, #T_78ced_row26_col3, #T_78ced_row28_col3, #T_78ced_row29_col3, #T_78ced_row31_col3, #T_78ced_row32_col3, #T_78ced_row36_col3, #T_78ced_row42_col3, #T_78ced_row45_col3, #T_78ced_row46_col3, #T_78ced_row47_col3, #T_78ced_row48_col3, #T_78ced_row55_col3, #T_78ced_row64_col3, #T_78ced_row65_col3, #T_78ced_row76_col3, #T_78ced_row77_col3, #T_78ced_row82_col3, #T_78ced_row87_col3, #T_78ced_row95_col3 {
#   background-color: darkgray;
# }
# </style>
# <table id="T_78ced">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78ced_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_78ced_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_78ced_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_78ced_level0_col3" class="col_heading level0 col3" >Age</th>
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#                                               0.0/7.6 MB ? eta -:--:--
#      -                                        0.3/7.6 MB 5.9 MB/s eta 0:00:02
#      ---                                      0.8/7.6 MB 8.0 MB/s eta 0:00:01
#      -------                                  1.4/7.6 MB 9.7 MB/s eta 0:00:01
#      -----------                              2.1/7.6 MB 11.3 MB/s eta 0:00:01
#      ----------------                         3.1/7.6 MB 13.3 MB/s eta 0:00:01
#      -----------------------                  4.4/7.6 MB 15.6 MB/s eta 0:00:01
#      -------------------------------          6.1/7.6 MB 18.5 MB/s eta 0:00:01
#      ---------------------------------------  7.6/7.6 MB 20.3 MB/s eta 0:00:01
#      ---------------------------------------- 7.6/7.6 MB 18.8 MB/s eta 0:00:00
# ...
#                                               0.0/470.9 kB ? eta -:--:--
#      ---------------------------------------- 470.9/470.9 kB ? eta 0:00:00
# ...

# %%
import matplotlib

# %%
titanic_train2.tail(20).style.background_gradient(cmap='Blues')
titanic_train2.tail(20).style.background_gradient(cmap='Summer_r')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\formatters.py:342, in BaseFormatter.__call__(self, obj)
#     340     method = get_real_method(obj, self.print_method)
#     341     if method is not None:
# --> 342         return method()
#     343     return None
#     344 else:
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\style.py:383, in Styler._repr_html_(self)
#     378 """
#     379 Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     380 default if an object is returned at the end of a cell.
#     381 """
#     382 if get_option("styler.render.repr") == "html":
# --> 383     return self.to_html()
#     384 return None
#
# ...

# %%
# 출력포맷
titanic_train2.tail(20).style.format({'Fare' : '${:10,.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_78df2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78df2_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_78df2_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_78df2_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_78df2_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_78df2_level0_col4" class="col_heading level0 col4" >SibSp</th>
#       <th id="T_78df2_level0_col5" class="col_heading level0 col5" >Parch</th>
#       <th id="T_78df2_level0_col6" class="col_heading level0 col6" >Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78df2_level0_row0" class="row_heading level0 row0" >871</th>
#       <td id="T_78df2_row0_col0" class="data row0 col0" >872</td>
#       <td id="T_78df2_row0_col1" class="data row0 col1" >1</td>
# ...
